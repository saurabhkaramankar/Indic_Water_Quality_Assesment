# %% [markdown]
# ## Indian Water Quality Assesment

# %%
import pandas as pd
import numpy as np
import os

# %%
dataset=pd.read_csv('water_dataX.csv',encoding="ISO-8859-1")
dataset.fillna(0, inplace=True)
dataset.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (µmhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
# 2          GOA  29.5         6.3  6.9                     179           1.7
# 3          GOA  29.7         5.8  6.9                      64           3.8
# 4          GOA  29.5         5.8  7.3                      83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0                              0.1                         11
# 1                              0.2                       4953
# 2                              0.1                       3243
# 3                              0.5                       5382
# 4                              0.4                       3428
#
#   TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                             27  2014
# 1                           8391  2014
# 2                           5330  2014
# 3                           8443  2014
# 4                           5500  2014

# %%
dataset.dtypes
# Out:
# STATION CODE                        object
# LOCATIONS                           object
# STATE                               object
# Temp                                object
# D.O. (mg/l)                         object
# PH                                  object
# CONDUCTIVITY (µmhos/cm)             object
# B.O.D. (mg/l)                       object
# NITRATENAN N+ NITRITENANN (mg/l)    object
# FECAL COLIFORM (MPN/100ml)          object
# TOTAL COLIFORM (MPN/100ml)Mean      object
# year                                 int64
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (µmhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
#  11  year                              1991 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 186.8+ KB

# %%
dataset.describe()
# Out:
#               year
# count  1991.000000
# mean   2010.038172
# std       3.057333
# min    2003.000000
# 25%    2008.000000
# 50%    2011.000000
# 75%    2013.000000
# max    2014.000000

# %%
#conversions
#converting all non nuerical values to NaN
dataset['Temp']=pd.to_numeric(dataset['Temp'],errors='coerce')
dataset['D.O. (mg/l)']=pd.to_numeric(dataset['D.O. (mg/l)'],errors='coerce')
dataset['PH']=pd.to_numeric(dataset['PH'],errors='coerce')
dataset['B.O.D. (mg/l)']=pd.to_numeric(dataset['B.O.D. (mg/l)'],errors='coerce')
dataset['NITRATENAN N+ NITRITENANN (mg/l)']=pd.to_numeric(dataset['NITRATENAN N+ NITRITENANN (mg/l)'],errors='coerce')
dataset['TOTAL COLIFORM (MPN/100ml)Mean']=pd.to_numeric(dataset['TOTAL COLIFORM (MPN/100ml)Mean'],errors='coerce')
dataset.dtypes
# Out:
# STATION CODE                         object
# LOCATIONS                            object
# STATE                                object
# Temp                                float64
# D.O. (mg/l)                         float64
# PH                                  float64
# CONDUCTIVITY (µmhos/cm)              object
# B.O.D. (mg/l)                       float64
# NITRATENAN N+ NITRITENANN (mg/l)    float64
# FECAL COLIFORM (MPN/100ml)           object
# TOTAL COLIFORM (MPN/100ml)Mean      float64
# year                                  int64
# dtype: object

# %%
dataset.columns
# Out:
# Index(['STATION CODE', 'LOCATIONS', 'STATE', 'Temp', 'D.O. (mg/l)', 'PH',
#        'CONDUCTIVITY (µmhos/cm)', 'B.O.D. (mg/l)',
#        'NITRATENAN N+ NITRITENANN (mg/l)', 'FECAL COLIFORM (MPN/100ml)',
#        'TOTAL COLIFORM (MPN/100ml)Mean', 'year'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(dataset)

# %% [markdown]
# Skewness
#
# Skewness is a statistical property that measures the degree of asymmetry in a probability distribution. A dataset is considered to be skewed if it is not symmetric, meaning that it is not equally distributed on both sides of its central value. Skewness can be positive or negative, indicating that the tail of the distribution is longer on the right or left side, respectively. The degree of skewness is measured by the skewness coefficient, which is a standardized measure that indicates the degree and direction of skewness. Skewness is an important characteristic of data that can have implications for statistical analysis and modeling.
#
# There are two types of skewness: positive skewness and negative skewness. Positive skewness occurs when the tail of the distribution is longer on the right side, or in other words, there are more high values than low values. Negative skewness occurs when the tail of the distribution is longer on the left side, or in other words, there are more low values than high values.

# %%
dataset.skew()

# %%
sns.boxplot(dataset["Temprature"])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.countplot(x="year",data = dataset)
plt.title("Number of Years Record´s", fontweight="bold")

plt.subplot(1,2,2)
plt.pie(dataset["Grade"].value_counts().values,
       labels=list(dataset["year"].value_counts().index),
        wedgeprops = {"ec": "k"},
       textprops = {"fontsize":10},
       autopct="%1.0f%%")
plt.axis("equal")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9832\1074323741.py in <module>
#       4
#       5 plt.subplot(1,2,1)
# ----> 6 sns.countplot(x="Grade",data = dataset)
#       7 plt.title("Number of Grade Record´s", fontweight="bold")
#       8
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
#    3600         estimator, ci, n_boot, units, seed,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Grade'

# %%
pip install skimpy
# Out:
# Collecting skimpy
#   Downloading skimpy-0.0.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in c:\users\saurabh\anaconda3\lib\site-packages (from skimpy) (1.4.4)
# Collecting typeguard<3.0.0,>=2.12.1
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in c:\users\saurabh\anaconda3\lib\site-packages (from skimpy) (1.0.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\saurabh\anaconda3\lib\site-packages (from skimpy) (1.23.5)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in c:\users\saurabh\anaconda3\lib\site-packages (from skimpy) (2.11.2)
# Collecting click<9.0.0,>=8.1.3
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting rich<13.0,>=10.9
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ------------------------------------- 237.5/237.5 kB 40.6 kB/s eta 0:00:00
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in c:\users\saurabh\anaconda3\lib\site-packages (from skimpy) (6.15.2)
# Requirement already satisfied: colorama in c:\users\saurabh\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.3->skimpy) (0.4.5)
# Requirement already satisfied: nest-asyncio in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.5)
# Requirement already satisfied: psutil in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.3.4)
# Requirement already satisfied: packaging in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (21.3)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\saurabh\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.31.1)
# Requirement already satisfied: notebook in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.12)
# Requirement already satisfied: jupyter-console in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.3)
# Requirement already satisfied: ipywidgets in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.6.5)
# Requirement already satisfied: nbconvert in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.4)
# Requirement already satisfied: qtconsole in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (5.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\saurabh\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saurabh\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2022.1)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      --------------------------------------- 51.1/51.1 kB 96.7 kB/s eta 0:00:00
# Requirement already satisfied: jedi>=0.16 in c:\users\saurabh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: decorator in c:\users\saurabh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\saurabh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\saurabh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (63.4.1)
# Requirement already satisfied: pickleshare in c:\users\saurabh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: backcall in c:\users\saurabh\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: entrypoints in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (4.11.1)
# Requirement already satisfied: six>=1.5 in c:\users\saurabh\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.2->skimpy) (1.16.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\saurabh\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\saurabh\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\saurabh\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\saurabh\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (5.5.0)
# Requirement already satisfied: defusedxml in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.13)
# Requirement already satisfied: bleach in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.5.0)
# Requirement already satisfied: jinja2>=2.4 in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.11.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.1.2)
# Requirement already satisfied: testpath in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\saurabh\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.8.4)
# Requirement already satisfied: argon2-cffi in c:\users\saurabh\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\saurabh\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\saurabh\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\saurabh\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\saurabh\anaconda3\lib\site-packages (from packaging->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.9)
# Requirement already satisfied: qtpy in c:\users\saurabh\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->skimpy) (2.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\saurabh\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\saurabh\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\saurabh\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\saurabh\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\saurabh\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\saurabh\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\saurabh\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\saurabh\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saurabh\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\saurabh\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\saurabh\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\saurabh\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (21.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\saurabh\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\saurabh\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.21)
# Installing collected packages: commonmark, typeguard, rich, click, skimpy
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
# Successfully installed click-8.1.3 commonmark-0.9.1 rich-12.6.0 skimpy-0.0.8 typeguard-2.13.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/skimpy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/skimpy/

# %%
from skimpy import skim
skim(dataset)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1991   │ │ string      │ 11    │                                                          │
# │ │ Number of columns │ 12     │ │ int32       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┓  │
# │ ┃ column_name        ┃ NA   ┃ NA %    ┃ mean    ┃ sd     ┃ p0      ┃ p25     ┃ p75     ┃ p100    ┃ hist      ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━┩  │
# │ │ year               │    0 │       0 │    2000 │    3.1 │    2000 │    2000 │    2000 │    2000 │  ▁▃▄▆██   │  │
# │ └────────────────────┴──────┴─────────┴─────────┴────────┴─────────┴─────────┴─────────┴─────────┴───────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                           ┃ NA    ┃ NA %      ┃ words per row            ┃ total words         ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ STATION CODE                          │     0 │         0 │                        1 │                2000 │  │
# │ │ LOCATIONS                             │     0 │         0 │                        1 │                2000 │  │
# │ │ STATE                                 │     0 │         0 │                        1 │                2000 │  │
# │ │ Temp                                  │     0 │         0 │                        1 │                2000 │  │
# │ │ D.O. (mg/l)                           │     0 │         0 │                        1 │                2000 │  │
# │ │ PH                                    │     0 │         0 │                        1 │                2000 │  │
# │ │ CONDUCTIVITY (µmhos/                  │     0 │         0 │                        1 │                2000 │  │
# │ │ B.O.D. (mg/l)                         │     0 │         0 │                        1 │                2000 │  │
# │ │ NITRATENAN N+ NITRIT                  │     0 │         0 │                        1 │                2000 │  │
# │ │ FECAL COLIFORM (MPN/                  │     0 │         0 │                        1 │                2000 │  │
# │ │ TOTAL COLIFORM (MPN/                  │     0 │         0 │                        1 │                2000 │  │
# │ └───────────────────────────────────────┴───────┴───────────┴──────────────────────────┴─────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
#initialization
start=2
end=1779
station=dataset.iloc [start:end ,0]
location=dataset.iloc [start:end ,1]
state=dataset.iloc [start:end ,2]
do= dataset.iloc [start:end ,4].astype(np.float64)
value=0
ph = dataset.iloc[ start:end,5]  
co = dataset.iloc [start:end ,6].astype(np.float64)   
  
year=dataset.iloc[start:end,11]
tc=dataset.iloc [2:end ,10].astype(np.float64)


bod = dataset.iloc [start:end ,7].astype(np.float64)
na= dataset.iloc [start:end ,8].astype(np.float64)
na.dtype
# Out:
# dtype('float64')

# %%
data=pd.concat([station,location,state,do,ph,co,bod,na,tc,year],axis=1)
data. columns = ['station','location','state','do','ph','co','bod','na','tc','year']

# %%
#calulation of Ph
data['npH']=data.ph.apply(lambda x: (100 if (8.5>=x>=7)  
                                 else(80 if  (8.6>=x>=8.5) or (6.9>=x>=6.8) 
                                      else(60 if (8.8>=x>=8.6) or (6.8>=x>=6.7) 
                                          else(40 if (9>=x>=8.8) or (6.7>=x>=6.5)
                                              else 0)))))

# %%
#calculation of dissolved oxygen
data['ndo']=data.do.apply(lambda x:(100 if (x>=6)  
                                 else(80 if  (6>=x>=5.1) 
                                      else(60 if (5>=x>=4.1)
                                          else(40 if (4>=x>=3) 
                                              else 0)))))

# %%
#calculation of total coliform
data['nco']=data.tc.apply(lambda x:(100 if (5>=x>=0)  
                                 else(80 if  (50>=x>=5) 
                                      else(60 if (500>=x>=50)
                                          else(40 if (10000>=x>=500) 
                                              else 0)))))

# %%
#calc of B.D.O
data['nbdo']=data.bod.apply(lambda x:(100 if (3>=x>=0)  
                                 else(80 if  (6>=x>=3) 
                                      else(60 if (80>=x>=6)
                                          else(40 if (125>=x>=80) 
                                              else 0)))))

# %%
#calculation of electrical conductivity
data['nec']=data.co.apply(lambda x:(100 if (75>=x>=0)  
                                 else(80 if  (150>=x>=75) 
                                      else(60 if (225>=x>=150)
                                          else(40 if (300>=x>=225) 
                                              else 0)))))

# %%
#Calulation of nitrate
data['nna']=data.na.apply(lambda x:(100 if (20>=x>=0)  
                                 else(80 if  (50>=x>=20) 
                                      else(60 if (100>=x>=50)
                                          else(40 if (200>=x>=100) 
                                              else 0)))))

data.head()
data.dtypes
# Out:
# station      object
# location     object
# state        object
# do          float64
# ph          float64
# co          float64
# bod         float64
# na          float64
# tc          float64
# year          int64
# npH           int64
# ndo           int64
# nco           int64
# nbdo          int64
# nec           int64
# nna           int64
# dtype: object

# %%
data['wph']=data.npH * 0.165
data['wdo']=data.ndo * 0.281
data['wbdo']=data.nbdo * 0.234
data['wec']=data.nec* 0.009
data['wna']=data.nna * 0.028
data['wco']=data.nco * 0.281
data['wqi']=data.wph+data.wdo+data.wbdo+data.wec+data.wna+data.wco 
data
# Out:
#      station                                           location state      do  \
# 2       1475                                ZUARI AT PANCHAWADI   GOA   6.300
# 3       3181                        RIVER ZUARI AT BORIM BRIDGE   GOA   5.800
# 4       3182                       RIVER ZUARI AT MARCAIM JETTY   GOA   5.800
# 5       1400             MANDOVI AT NEGHBOURHOOD OF PANAJI, GOA   GOA   5.500
# 6       1476                     MANDOVI AT TONCA, MARCELA, GOA   GOA   6.100
# ...      ...                                                ...   ...     ...
# 1774    1428  KHARKHLA NEAR SUTNGA KHLIERIAT,JAINTIA HILLS D...   NAN   4.600
# 1775    1631                      MYNTDU RIVER JOWAI, MEGHALAYA   NAN   8.800
# 1776    1632                        GANOL RIVER TURA, MEGHALAYA   NAN  10.000
# 1777    1633              SIMSANG RIVER WILLIAMNAGAR, MEGHALAYA   NAN   9.000
# 1778    2050                             TLAWNG UPSTREAM AIZAWL   NAN   7.767
#
#          ph     co  bod   na      tc  year  ...  nbdo  nec  nna   wph    wdo  \
# 2     6.900  179.0  1.7  0.1  5330.0  2014  ...   100   60  100  13.2  28.10
# 3     6.900   64.0  3.8  0.5  8443.0  2014  ...    80  100  100  13.2  22.48
# 4     7.300   83.0  1.9  0.4  5500.0  2014  ...   100   80  100  16.5  22.48
# 5     7.400   81.0  1.5  0.1  4049.0  2014  ...   100   80  100  16.5  22.48
# 6     6.700  308.0  1.4  0.3  5672.0  2014  ...   100    0  100   9.9  28.10
# ...     ...    ...  ...  ...     ...   ...  ...   ...  ...  ...   ...    ...
# 1774  3.000  350.0  6.2  2.2    49.0  2006  ...    60    0  100   0.0  16.86
# 1775  7.000  172.0  1.6  5.0  2800.0  2006  ...   100   60  100  16.5  28.10
# 1776  7.100  150.0  1.0  4.0   350.0  2006  ...   100   80  100  16.5  28.10
# 1777  7.300  158.0  1.8  7.2   280.0  2006  ...   100   60  100  16.5  28.10
# 1778  7.543    NaN  0.5  NaN     NaN  2006  ...   100    0    0  16.5  28.10
#
#        wbdo   wec  wna    wco    wqi
# 2     23.40  0.54  2.8  11.24  79.28
# 3     18.72  0.90  2.8  11.24  69.34
# 4     23.40  0.72  2.8  11.24  77.14
# 5     23.40  0.72  2.8  11.24  77.14
# 6     23.40  0.00  2.8  11.24  75.44
# ...     ...   ...  ...    ...    ...
# 1774  14.04  0.00  2.8  22.48  56.18
# 1775  23.40  0.54  2.8  11.24  82.58
# 1776  23.40  0.72  2.8  16.86  88.38
# 1777  23.40  0.54  2.8  16.86  88.20
# 1778  23.40  0.00  0.0   0.00  68.00
#
# [1777 rows x 23 columns]

# %%
#calculation overall wqi for each year
ag=data.groupby('year')['wqi'].mean()
ag.head()
# Out:
# year
# 2006    71.308824
# 2007    72.549000
# 2008    72.570943
# 2009    74.085193
# 2010    74.648723
# Name: wqi, dtype: float64

# %%
data=ag.reset_index(level=0,inplace=False)
data
# Out:
#    year        wqi
# 0  2006  71.308824
# 1  2007  72.549000
# 2  2008  72.570943
# 3  2009  74.085193
# 4  2010  74.648723
# 5  2011  75.647013
# 6  2012  78.969041
# 7  2013  75.009425
# 8  2014  76.879588

# %%
#visualizing the filttered data

year=data['year'].values
AQI=data['wqi'].values
data['wqi']=pd.to_numeric(data['wqi'],errors='coerce')
data['year']=pd.to_numeric(data['year'],errors='coerce')

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(year,AQI, color='red')
plt.show()
data
# Out:
# C:\Users\SAURABH\AppData\Local\Temp\ipykernel_9832\2557461385.py:12: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
#    year        wqi
# 0  2006  71.308824
# 1  2007  72.549000
# 2  2008  72.570943
# 3  2009  74.085193
# 4  2010  74.648723
# 5  2011  75.647013
# 6  2012  78.969041
# 7  2013  75.009425
# 8  2014  76.879588

# %%
data = data[np.isfinite(data['wqi'])]
data.head()
# Out:
#    year        wqi
# 0  2006  71.308824
# 1  2007  72.549000
# 2  2008  72.570943
# 3  2009  74.085193
# 4  2010  74.648723

# %%
#scatter plot of data points
cols =['year']
y = data['wqi']
x=data[cols]

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
data=data.set_index('year')
data.plot(figsize=(15,6))
plt.show()

# %%
from sklearn import neighbors,datasets
data=data.reset_index(level=0,inplace=False)
data
# Out:
#    year        wqi
# 0  2006  71.308824
# 1  2007  72.549000
# 2  2008  72.570943
# 3  2009  74.085193
# 4  2010  74.648723
# 5  2011  75.647013
# 6  2012  78.969041
# 7  2013  75.009425
# 8  2014  76.879588

# %%
#using linear regression to predict
from sklearn import linear_model
from sklearn.model_selection import train_test_split
cols =['year']
y = data['wqi']
x=data[cols]
reg=linear_model.LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
a=reg.predict(x_test)
a
# Out:
# array([73.86206246, 74.59948715])

# %%
y_test
# Out:
# 3    74.085193
# 4    74.648723
# Name: wqi, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
print('mse:%.2f'%mean_squared_error(y_test,a))
# Out:
# mse:0.03

# %%
dt = pd.DataFrame({'Actual': y_test, 'Predicted': a}) 
#using gradient descent to optimize it further
x = (x - x.mean()) / x.std()
x = np.c_[np.ones(x.shape[0]), x]
x
# Out:
# array([[ 1.        , -1.46059349],
#        [ 1.        , -1.09544512],
#        [ 1.        , -0.73029674],
#        [ 1.        , -0.36514837],
#        [ 1.        ,  0.        ],
#        [ 1.        ,  0.36514837],
#        [ 1.        ,  0.73029674],
#        [ 1.        ,  1.09544512],
#        [ 1.        ,  1.46059349]])

# %%
alpha = 0.1 #Step size
iterations = 3000 #No. of iterations
m = y.size #No. of data points
np.random.seed(4) #Setting the seed
theta = np.random.rand(2) #Picking some random values to start with

def gradient_descent(x, y, theta, iterations, alpha):
    past_costs = []
    past_thetas = [theta]
    for i in range(iterations):
        prediction = np.dot(x, theta)
        error = prediction - y
        cost = 1/(2*m) * np.dot(error.T, error)
        past_costs.append(cost)
        theta = theta - (alpha * (1/m) * np.dot(x.T, error))
        past_thetas.append(theta)
        
    return past_thetas, past_costs

past_thetas, past_costs = gradient_descent(x, y, theta, iterations, alpha)
theta = past_thetas[-1]

#Print the results...
print("Gradient Descent: {:.2f}, {:.2f}".format(theta[0], theta[1]))
# Out:
# Gradient Descent: 74.63, 2.01

# %%
plt.title('Cost Function J')
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
plt.plot(past_costs)
plt.show()

# %%
#prediction of january(2013-2015) across india
import numpy as np
newB=[74.76, 2.13]

def rmse(y,y_pred):
    rmse= np.sqrt(sum(y-y_pred))
    return rmse
   

y_pred=x.dot(newB)

dt = pd.DataFrame({'Actual': y, 'Predicted': y_pred})  
dt=pd.concat([data, dt], axis=1)
dt
# Out:
#    year        wqi     Actual  Predicted
# 0  2006  71.308824  71.308824  71.648936
# 1  2007  72.549000  72.549000  72.426702
# 2  2008  72.570943  72.570943  73.204468
# 3  2009  74.085193  74.085193  73.982234
# 4  2010  74.648723  74.648723  74.760000
# 5  2011  75.647013  75.647013  75.537766
# 6  2012  78.969041  78.969041  76.315532
# 7  2013  75.009425  75.009425  77.093298
# 8  2014  76.879588  76.879588  77.871064

# %%
#testing the accuracy of the model

from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y,y_pred)))
# Out:
# 1.1987755149740729

# %%
#plotting the actual and predicted results
x_axis=dt.year
y_axis=dt.Actual
y1_axis=dt.Predicted
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,y1_axis,color='r')
plt.title("linear regression")

plt.show()

# %%
from sklearn.linear_model import LogisticRegression
logistic = LogisticRegression()
logistic.fit(X_train,y_train)
LogisticRegression()
# Predicting the Test set Results
y_pred_logistic = logistic.predict(X_test)
np.set_printoptions()
print(np.concatenate((y_pred_logistic.reshape(len(y_pred_logistic),1), y_test.reshape(len(y_test),1)), axis=1))

# %%
# Making the Confusion Matrix and See Some Metrics
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_pred_logistic))

# %%
cm = confusion_matrix(y_test,y_pred_logistic)
p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt="g")
plt.title('Logistic Regression Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
# K-Fold Cross Validation
from sklearn.model_selection import cross_val_score
accuracies_logistic = cross_val_score(estimator = logistic, X = X_train, y = y_train, cv = 10)
print("Logistic Regression Accuracy: {:.2f} %".format(accuracies_logistic.mean() * 100))
print("Logistic Regression Standard Deviation: {:.2f} %".format(accuracies_logistic.std() * 100))

# %%
#Hyperparameter Tunning

from sklearn.model_selection import GridSearchCV
# create logistic regression model
lr = LogisticRegression()

# define hyperparameters to tune
param_grid = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'max_iter': [100, 500, 1000]
}

# define grid search with 5-fold cross-validation
grid = GridSearchCV(lr, param_grid, cv=5, verbose=1, n_jobs=-1)

# fit grid search to the data
grid.fit(X_train, y_train)

# print best hyperparameters and accuracy score
print("Best hyperparameters: ", grid.best_params_)
print("Best accuracy score: ", grid.best_score_)

# %%
#Taking the avg of the yearly water quality index and grouping it yearly
yearly = data.groupby('year')['wqi'].mean()

# %%
yearly
# Out:
# year
# 2006    71.308824
# 2007    72.549000
# 2008    72.570943
# 2009    74.085193
# 2010    74.648723
# 2011    75.647013
# 2012    78.969041
# 2013    75.009425
# 2014    76.879588
# Name: wqi, dtype: float64

# %%
dataset['CONDUCTIVITY (µmhos/cm)']=pd.to_numeric(dataset['CONDUCTIVITY (µmhos/cm)'],errors='coerce')

# %%
dataset.isna()
# Out:
#       STATION CODE  LOCATIONS  STATE   Temp  D.O. (mg/l)     PH  \
# 0            False      False  False  False        False  False
# 1            False      False  False  False        False  False
# 2            False      False  False  False        False  False
# 3            False      False  False  False        False  False
# 4            False      False  False  False        False  False
# ...            ...        ...    ...    ...          ...    ...
# 1986         False      False  False   True        False  False
# 1987         False      False  False  False        False  False
# 1988         False      False  False  False        False  False
# 1989         False      False  False  False        False  False
# 1990         False      False  False  False        False  False
#
#       CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  \
# 0                       False           True
# 1                       False          False
# 2                       False          False
# 3                       False          False
# 4                       False          False
# ...                       ...            ...
# 1986                    False          False
# 1987                    False          False
# 1988                    False          False
# 1989                    False          False
# 1990                    False          False
#
#       NITRATENAN N+ NITRITENANN (mg/l)  FECAL COLIFORM (MPN/100ml)  \
# 0                                False                       False
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
# ...                                ...                         ...
# 1986                             False                       False
# 1987                             False                       False
# 1988                              True                       False
# 1989                              True                       False
# 1990                              True                       False
#
#       TOTAL COLIFORM (MPN/100ml)Mean   year
# 0                              False  False
# 1                              False  False
# 2                              False  False
# 3                              False  False
# 4                              False  False
# ...                              ...    ...
# 1986                           False  False
# 1987                           False  False
# 1988                           False  False
# 1989                           False  False
# 1990                           False  False
#
# [1991 rows x 12 columns]

# %%
data = data.dropna()
data.isna()
# Out:
#     year    wqi
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False
# 6  False  False
# 7  False  False
# 8  False  False

# %%
datax = dataset.dropna()
datax.isna()
# Out:
#       STATION CODE  LOCATIONS  STATE   Temp  D.O. (mg/l)     PH  \
# 1            False      False  False  False        False  False
# 2            False      False  False  False        False  False
# 3            False      False  False  False        False  False
# 4            False      False  False  False        False  False
# 5            False      False  False  False        False  False
# ...            ...        ...    ...    ...          ...    ...
# 1981         False      False  False  False        False  False
# 1982         False      False  False  False        False  False
# 1984         False      False  False  False        False  False
# 1985         False      False  False  False        False  False
# 1987         False      False  False  False        False  False
#
#       CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  \
# 1                       False          False
# 2                       False          False
# 3                       False          False
# 4                       False          False
# 5                       False          False
# ...                       ...            ...
# 1981                    False          False
# 1982                    False          False
# 1984                    False          False
# 1985                    False          False
# 1987                    False          False
#
#       NITRATENAN N+ NITRITENANN (mg/l)  FECAL COLIFORM (MPN/100ml)  \
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
# 5                                False                       False
# ...                                ...                         ...
# 1981                             False                       False
# 1982                             False                       False
# 1984                             False                       False
# 1985                             False                       False
# 1987                             False                       False
#
#       TOTAL COLIFORM (MPN/100ml)Mean   year
# 1                              False  False
# 2                              False  False
# 3                              False  False
# 4                              False  False
# 5                              False  False
# ...                              ...    ...
# 1981                           False  False
# 1982                           False  False
# 1984                           False  False
# 1985                           False  False
# 1987                           False  False
#
# [1599 rows x 12 columns]

# %%
dataset.tail()
# Out:
#      STATION CODE                                          LOCATIONS STATE  \
# 1986         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU   NAN
# 1987         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...   NAN
# 1988         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA   NAN
# 1989         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA   NAN
# 1990         1726   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA   NAN
#
#       Temp  D.O. (mg/l)     PH  CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  \
# 1986   NaN          7.9  738.0                      7.2            2.7
# 1987  29.0          7.5  585.0                      6.3            2.6
# 1988  28.0          7.6   98.0                      6.2            1.2
# 1989  28.0          7.7   91.0                      6.5            1.3
# 1990  29.0          7.6  110.0                      5.7            1.1
#
#       NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 1986                             0.518                      0.518
# 1987                             0.155                      0.155
# 1988                               NaN                        NAN
# 1989                               NaN                        NAN
# 1990                               NaN                        NAN
#
#       TOTAL COLIFORM (MPN/100ml)Mean  year
# 1986                           202.0  2003
# 1987                           315.0  2003
# 1988                           570.0  2003
# 1989                           562.0  2003
# 1990                           546.0  2003

# %%
datax['wph']=datax.npH * 0.165
datax['wdo']=datax.ndo * 0.281
datax['wbdo']=datax.nbdo * 0.234
datax['wec']=datax.nec* 0.009
datax['wna']=datax.nna * 0.028
datax['wco']=datax.nco * 0.281
datax['wqi']=datax.wph+datax.wdo+datax.wbdo+datax.wec+datax.wna+datax.wco 
datax.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9832\3028474273.py in <module>
# ----> 1 datax['wph']=datax.npH * 0.165
#       2 datax['wdo']=datax.ndo * 0.281
#       3 datax['wbdo']=datax.nbdo * 0.234
#       4 datax['wec']=datax.nec* 0.009
#       5 datax['wna']=datax.nna * 0.028
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'npH'

# %%
data['wph']=data.npH * 0.165
data['wdo']=data.ndo * 0.281
data['wbdo']=data.nbdo * 0.234
data['wec']=data.nec* 0.009
data['wna']=data.nna * 0.028
data['wco']=data.nco * 0.281
data['wqi']=data.wph+data.wdo+data.wbdo+data.wec+data.wna+data.wco 
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9832\2935183327.py in <module>
# ----> 1 data['wph']=data.npH * 0.165
#       2 data['wdo']=data.ndo * 0.281
#       3 data['wbdo']=data.nbdo * 0.234
#       4 data['wec']=data.nec* 0.009
#       5 data['wna']=data.nna * 0.028
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'npH'

# %%
yearly_wqi = yearly.reset_index(level=0,inplace=False)
yearly_wqi
# Out:
#    year        wqi
# 0  2006  71.308824
# 1  2007  72.549000
# 2  2008  72.570943
# 3  2009  74.085193
# 4  2010  74.648723
# 5  2011  75.647013
# 6  2012  78.969041
# 7  2013  75.009425
# 8  2014  76.879588

# %%
#Data Visualisation Here
import matplotlib.pyplot as plt
yearly_wqi=yearly_wqi.set_index('year')
yearly_wqi.plot(figsize=(15,6))
plt.show()

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(yearly_wqi)
pyplot.show()
# Out:
# C:\Users\SAURABH\AppData\Local\Temp\ipykernel_9832\3363775319.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
series = yearly_wqi
###Training a Rolling forecast ARIMA Model and Evaluating the results
# evaluate an ARIMA model using a walk-forward validation
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# split into train and test sets
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# Out:
# C:\Users\SAURABH\AppData\Local\Temp\ipykernel_9832\1319517901.py:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
# walk-forward validation
for t in range(len(test)):
    model = ARIMA(X, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# C:\Users\SAURABH\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# predicted=77.387763, expected=75.647013
# predicted=77.387763, expected=78.969041
# predicted=77.387763, expected=75.009425
# predicted=77.387763, expected=76.879588

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test RMSE: 1.692

# %%
###Training an ARIMA Model and Residual error plot
# fit an ARIMA model and plot residual errors
from pandas import datetime
from pandas import read_csv
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot

# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
# C:\Users\SAURABH\AppData\Local\Temp\ipykernel_9832\2938392194.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# C:\Users\SAURABH\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\SAURABH\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\SAURABH\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\SAURABH\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    wqi   No. Observations:                    9
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                 -15.922
# Date:                Sun, 21 May 2023   AIC                             43.843
# Time:                        21:04:12   BIC                             44.320
# Sample:                             0   HQIC                            40.629
#                                   - 9
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4067      4.121     -0.099      0.921      -8.483       7.670
# ar.L2          0.0461      6.424      0.007      0.994     -12.545      12.637
# ar.L3          0.3833      4.711      0.081      0.935      -8.850       9.617
# ar.L4          0.0744      6.859      0.011      0.991     -13.369      13.518
# ar.L5          0.1843     21.169      0.009      0.993     -41.306      41.674
# sigma2         2.8015     37.026      0.076      0.940     -69.769      75.372
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):                 1.06
# Prob(Q):                              0.61   Prob(JB):                         0.59
# Heteroskedasticity (H):               5.35   Skew:                            -0.86
# Prob(H) (two-sided):                  0.20   Kurtosis:                         3.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                0
# count   9.000000
# mean    8.409210
# std    23.643250
# min    -2.987205
# 25%     0.526710
# 50%     1.036346
# 75%     1.589489
# max    71.308824
